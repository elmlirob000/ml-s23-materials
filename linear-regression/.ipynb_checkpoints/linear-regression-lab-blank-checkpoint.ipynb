# %% [markdown]
# # Linear Regression Lab

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("housing.csv")
df
# Out:
#     sqft  bedrooms   price
# 0   2104         3  399900
# 1   1600         3  329900
# 2   2400         3  369000
# 3   1416         2  232000
# 4   3000         4  539900
# 5   1985         4  299900
# 6   1534         3  314900
# 7   1427         3  198999
# 8   1380         3  212000
# 9   1494         3  242500
# 10  1940         4  239999
# 11  2000         3  347000
# 12  1890         3  329999
# 13  4478         5  699900
# 14  1268         3  259900
# 15  2300         4  449900
# 16  1320         2  299900
# 17  1236         3  199900
# 18  2609         4  499998
# 19  3031         4  599000
# 20  1767         3  252900
# 21  1888         2  255000
# 22  1604         3  242900
# 23  1962         4  259900
# 24  3890         3  573900
# 25  1100         3  249900
# 26  1458         3  464500
# 27  2526         3  469000
# 28  2200         3  475000
# 29  2637         3  299900
# 30  1839         2  349900
# 31  1000         1  169900
# 32  2040         4  314900
# 33  3137         3  579900
# 34  1811         4  285900
# 35  1437         3  249900
# 36  1239         3  229900
# 37  2132         4  345000
# 38  4215         4  549000
# 39  2162         4  287000
# 40  1664         2  368500
# 41  2238         3  329900
# 42  2567         4  314000
# 43  1200         3  299000
# 44   852         2  179900
# 45  1852         4  299900
# 46  1203         3  239500

# %%
# Set up our training data
x_train = df['sqft'].to_numpy() # Putting in [:2] would provide a slice of the data (just two points) instead of all
y_train = df['price'].to_numpy() 

# To use only a subset of the training data, use a slice of the arrays above.

print("Training data for x: ", x_train)
print("Training data for y: ", y_train)
# Out:
# Training data for x:  [2104 1600 2400 1416 3000 1985 1534 1427 1380 1494 1940 2000 1890 4478
#  1268 2300 1320 1236 2609 3031 1767 1888 1604 1962 3890 1100 1458 2526
#  2200 2637 1839 1000 2040 3137 1811 1437 1239 2132 4215 2162 1664 2238
#  2567 1200  852 1852 1203]
# Training data for y:  [399900 329900 369000 232000 539900 299900 314900 198999 212000 242500
#  239999 347000 329999 699900 259900 449900 299900 199900 499998 599000
#  252900 255000 242900 259900 573900 249900 464500 469000 475000 299900
#  349900 169900 314900 579900 285900 249900 229900 345000 549000 287000
#  368500 329900 314000 299000 179900 299900 239500]

# %%
# Make a nice plot

plt.scatter(x_train, y_train)
plt.show()

# %%
# Make a nice plot with a line based on the equation y = wx + b

plt.scatter(x_train, y_train)

# Set up dummy values for w and b
w = 170
b = 1000
 
# Generate points on our line y = wx + b to graph
line_x_points = np.linspace(min(x_train), max(x_train), 100) # linspace generates a bunch of numbers between the minimum x coordinate and the max
line_y_points = [w * x + b for x in line_x_points]

plt.plot(line_x_points, line_y_points, c='red')
plt.show()

# %%
# Let's turn it into a function:

def make_plot(x_train, y_train, w, b):
    plt.scatter(x_train, y_train)

    line_x_points = np.linspace(min(x_train), max(x_train), 100)
    line_y_points = [w * x + b for x in line_x_points]
    
    plt.plot(line_x_points, line_y_points, c='red')
    plt.show()
    
make_plot(x_train, y_train, 170, 1000)

# %%
# Let's define a function to predict y = f(x) = wx + b

def make_prediction(x, w, b):
    # CODE HERE
    return w * x + b
    # pass

# %%
# Let's define a function to compute the cost J(w, b) on a set of data:

def compute_cost(x_data, y_data, w, b):
    """
    x_data and y_data are lists
    w and b are scalars
    return: cost
    """
    m = len(x_data)
    total_cost = 0
    
    for i in range(0,m):
        y = y_data[i] # this is the y_hat(i) in the formula
        y_hat = make_prediction(x_data[i], w, b)
        cost = (y_hat - y) ** 2 # This is squaring in python
        total_cost += cost
    
    
    return total_cost / (2 * m) # do not have to cast, yay
    # CODE HERE
    # pass

# %%
# Output total cost for our data set:

w = 170
b = 1000

# Whatever w and b you choose, you want the cost to be minimized
# you can return two values in python by doing return x, y

print(compute_cost(x_train, y_train, w, b))
# Out:
# 2447314647.9468083

# %%
# Let's write a function to compute the gradient:

def compute_gradient(x_data, y_data, w, b):
    """
    x_data and y_data are lists
    w and b are scalars
    return: gradient of w, gradient of b
    """
    m = len(x_data)
    gradient_w = 0
    gradient_b = 0
    
    for i in range(0,m):
        y = y_data[i] # this is the y(i) in the formula
        y_hat = make_prediction(x_data[i], w, b)
        
        grad_w = (y_hat - y) * x_data[i]
        gradient_w += grad_w
        
        grad_b = y_hat - y
        gradient_b += grad_b
        
    return gradient_w / m, gradient_b / m
    
    # CODE HERE

# %%
# Let's write code to run gradient descent:

w = 0
b = 0
ALPHA = .0000001

# CODE HERE


for i in range(0, 10):
    print("Iteration", i)
    print("w = ", w, "b = ", b)
    print("The cost is ", compute_cost(x_train, y_train, w, b))
    
    gradient_w, gradient_b = compute_gradient(x_train, y_train, w, b)
          
    w = w - ALPHA * gradient_w
    b = b - ALPHA * gradient_b
    
    
print("Final w and b:", w, b)
# Out:
# Iteration 0
# w =  0 b =  0
# The cost is  65591548106.45744
# Iteration 1
# w =  76.42091281914892 b =  0.03404126595744681
# The cost is  20683190996.094822
# Iteration 2
# w =  117.52894978083218 b =  0.05279314282095807
# The cost is  7688791732.504553
# Iteration 3
# w =  139.6416233117901 b =  0.06332061157187525
# The cost is  3928814229.591943
# Iteration 4
# w =  151.53638558222823 b =  0.06942403902012421
# The cost is  2840850823.567704
# Iteration 5
# w =  157.93476917538456 b =  0.07314770354778821
# The cost is  2526044580.926727
# Iteration 6
# w =  161.37656234669947 b =  0.07559125534982687
# The cost is  2434954223.612467
# Iteration 7
# w =  163.22795801526314 b =  0.07734621393839315
# The cost is  2408596885.2985196
# Iteration 8
# w =  164.22385330809936 b =  0.0787307671652798
# The cost is  2400970285.495945
# Iteration 9
# w =  164.75956120023628 b =  0.07991607338950692
# The cost is  2398763494.171323
# Final w and b: 165.04772689394653 0.0809942014430472

# %%
# Let's plot the cost as a function of number of iterations of the
# gradient descent algorithm.

# CODE HERE

# %%
# Produce final plot of our data and our line:

make_plot(x_train, y_train, w, b)

# %%
# Make a new prediction:

sqft = 2000
prediction = make_prediction(sqft, w, b)

print("A house with", sqft, "square feet would sell for around", prediction, "dollars.")
# Out:
# A house with 2000 square feet would sell for around 0 dollars.
